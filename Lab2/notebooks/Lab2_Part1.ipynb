# %%
#import necessary packages
import arcpy
import requests as r
import ftplib

# %% [markdown]
# ## PART ONE

# %%
#Build the ETL to access LiDAR data files

from ftplib import FTP
ftp = FTP ('ftp.lmic.state.mn.us')
ftp.login()
ftp.cwd("/pub/data/elevation/lidar/projects/central_lakes/block_1/laz/")
ftp.retrlines('LIST')
# Out:
# -rw-rw-r--    4 12102    5070     35913178 Jan 30  2013 2726-06-27.laz
# -rw-rw-r--    3 12102    5070     40089261 Jan 30  2013 2726-06-28.laz
# -rw-rw-r--    3 12102    5070     37649506 Jan 30  2013 2726-06-29.laz
# -rw-rw-r--    3 12102    5070     37009402 Jan 30  2013 2726-06-30.laz
# -rw-rw-r--    3 12102    5070     35358516 Jan 30  2013 2726-06-31.laz
# -rw-rw-r--    3 12102    5070     35367160 Jan 30  2013 2726-06-32.laz
# -rw-rw-r--    3 12102    5070     22222990 Jan 30  2013 2726-06-33.laz
# -rw-rw-r--    3 12102    5070     25603211 Jan 30  2013 2726-06-34.laz
# -rw-rw-r--    3 12102    5070     28469581 Jan 30  2013 2726-06-35.laz
# -rw-rw-r--    3 12102    5070     33647349 Jan 30  2013 2726-06-36.laz
# -rw-rw-r--    3 12102    5070     46969666 Jan 30  2013 2726-06-37.laz
# -rw-rw-r--    3 12102    5070     41528097 Jan 30  2013 2726-06-38.laz
# -rw-rw-r--    3 12102    5070     43995686 Jan 30  2013 2726-06-39.laz
# ...

# %%
#select a file from the list and download in laz format

with open('2726-06-33.laz', 'wb') as fp:
    ftp.retrbinary('RETR 2726-06-33.laz', fp.write)

# %%
ftp.quit
# Out:
# <bound method FTP.quit of <ftplib.FTP object at 0x0000020BE8CC4B48>>

# %%
#use convert LAS to convert the LAZ to an LAS file

with arcpy.EnvManager(scratchWorkspace=r"C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\Lab2_GIS5572.gdb", workspace=r"C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\Lab2_GIS5572.gdb"):
    arcpy.conversion.ConvertLas(r"C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\2726-06-33.laz", r"C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572", "SAME_AS_INPUT", '', "NO_COMPRESSION", "REARRANGE_POINTS", r"C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\Lab2_GIS5572_LAS.lasd")

# %%
#now the LAS can be converted to a TIN

arcpy.env.workspace = r"C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572"

in_las_dataset = 'Lab2_GIS5572_LAS.lasd'

out_tin = 'TIN_Lab2'

# %%
arcpy.ddd.LasDatasetToTin(
    in_las_dataset, 
    out_tin, 
    'RANDOM', 
    'PERCENT', 
    50)
# Out:
# <Result 'C:\\Users\\celia\\Documents\\ArcGIS\\Projects\\Lab2_GIS5572\\TIN_Lab2'>

# %%
#do the same for a DEM

arcpy.conversion.LasDatasetToRaster(in_las_dataset, "DEM_Lab2", "ELEVATION", "BINNING AVERAGE LINEAR", "FLOAT", "CELLSIZE", 10, 1)
# Out:
# <Result 'C:\\Users\\celia\\Documents\\ArcGIS\\Projects\\Lab2_GIS5572\\DEM_Lab2'>

# %%
#first use the GUI to make two layouts, one of the TIN and one of the DEM
#then use Python to export a PDF of the DEM
aprx = arcpy.mp.ArcGISProject(r"C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\Lab2_GIS5572.aprx")
lyr = aprx.listLayouts("DEM_Layout")[0]
lyr.exportToPDF(r"C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\Lab2_DEM.pdf", resolution = 300)
# Out:
# 'C:\\Users\\celia\\Documents\\ArcGIS\\Projects\\Lab2_GIS5572\\Lab2_DEM.pdf'

# %%
#and of the TIN

aprx = arcpy.mp.ArcGISProject(r"C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\Lab2_GIS5572.aprx")
lyr = aprx.listLayouts("TIN_Layout")[0]
lyr.exportToPDF(r"C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\Lab2_TIN.pdf", resolution = 300)
# Out:
# 'C:\\Users\\celia\\Documents\\ArcGIS\\Projects\\Lab2_GIS5572\\Lab2_TIN.pdf'

# %% [markdown]
# ## PART THREE

# %%
#build the ETL to download the BIL files
#first create the URL

base = "http://services.nacse.org/prism/data/public/normals/4km/ppt/"

#resolution = '4km'
#element = 'ppt'
date = '_all'


r.get(base + date)

#URL.json()
# Out:
# <Response [200]>

# %%
#then unzip and save

from zipfile import ZipFile

# Create a ZipFile Object and load sample.zip in it
with ZipFile('PRISM_ppt_30yr_normal_4kmM2_all_bil.zip', 'r') as zipObj:
   # Extract all the contents of zip file in current directory
   zipObj.extractall()
    
input = PRISM_ppt_30yr_normal_4kmM2_all_bil.bil

# %%
#to create the timeseries, first project the bil files so they don't cause problems later
with arcpy.EnvManager(scratchWorkspace=r"C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\Lab2_GIS5572.gdb", workspace=r"C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\Lab2_GIS5572.gdb"):
    arcpy.Tmp.BatchProjectRaster(r"C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\PRISM_ppt_30yr_normal_4kmM2_all_bil\PRISM_ppt_30yr_normal_4kmM2_01_bil.bil;C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\PRISM_ppt_30yr_normal_4kmM2_all_bil\PRISM_ppt_30yr_normal_4kmM2_02_bil.bil;C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\PRISM_ppt_30yr_normal_4kmM2_all_bil\PRISM_ppt_30yr_normal_4kmM2_03_bil.bil;C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\PRISM_ppt_30yr_normal_4kmM2_all_bil\PRISM_ppt_30yr_normal_4kmM2_04_bil.bil;C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\PRISM_ppt_30yr_normal_4kmM2_all_bil\PRISM_ppt_30yr_normal_4kmM2_05_bil.bil;C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\PRISM_ppt_30yr_normal_4kmM2_all_bil\PRISM_ppt_30yr_normal_4kmM2_06_bil.bil;C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\PRISM_ppt_30yr_normal_4kmM2_all_bil\PRISM_ppt_30yr_normal_4kmM2_07_bil.bil;C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\PRISM_ppt_30yr_normal_4kmM2_all_bil\PRISM_ppt_30yr_normal_4kmM2_08_bil.bil;C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\PRISM_ppt_30yr_normal_4kmM2_all_bil\PRISM_ppt_30yr_normal_4kmM2_09_bil.bil;C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\PRISM_ppt_30yr_normal_4kmM2_all_bil\PRISM_ppt_30yr_normal_4kmM2_10_bil.bil;C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\PRISM_ppt_30yr_normal_4kmM2_all_bil\PRISM_ppt_30yr_normal_4kmM2_11_bil.bil;C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\PRISM_ppt_30yr_normal_4kmM2_all_bil\PRISM_ppt_30yr_normal_4kmM2_12_bil.bil", r"C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\Lab2_GIS5572.gdb\ProjectRaster_OutRaster_%Name%", "PROJCS['NAD_1983_UTM_Zone_15N',GEOGCS['GCS_North_American_1983',DATUM['D_North_American_1983',SPHEROID['GRS_1980',6378137.0,298.257222101]],PRIMEM['Greenwich',0.0],UNIT['Degree',0.0174532925199433]],PROJECTION['Transverse_Mercator'],PARAMETER['False_Easting',500000.0],PARAMETER['False_Northing',0.0],PARAMETER['Central_Meridian',-93.0],PARAMETER['Scale_Factor',0.9996],PARAMETER['Latitude_Of_Origin',0.0],UNIT['Meter',1.0]]", "NEAREST", "4874.84258818909 4874.84258818909", None, None, "GEOGCS['GCS_North_American_1983',DATUM['D_North_American_1983',SPHEROID['GRS_1980',6378137.0,298.257222101]],PRIMEM['Greenwich',0.0],UNIT['Degree',0.0174532925199433]]", "NO_VERTICAL")

# %%
#next convert bil to tiff since Arc does not like bil files
#I don't know why there's an error, this did work

arcpy.conversion.RasterToOtherFormat(r"C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\PRISM_ppt_30yr_normal_4kmM2_all_bil.bil", r"C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\Lab2_GIS5572.gdb", "TIFF")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# In  [21]:
# Line 3:     conversion.arcpy.RasterToOtherFormat("PRISM_ppt_30yr_normal_4kmM2_annual_bil.bil", r"C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572", "TIFF")
#
# NameError: name 'conversion' is not defined
# ---------------------------------------------------------------------------

# %%
#Create an empty mosaic dataset 
#Accidentally used my practice mosaic set, Gaudi, later on, so I changed it here to match

arcpy.management.CreateMosaicDataset(r"C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\Lab2_GIS5572.gdb", 
                                     "gaudi", "PROJCS['NAD_1983_UTM_Zone_15N',GEOGCS['GCS_North_American_1983',DATUM['D_North_American_1983',SPHEROID['GRS_1980',6378137.0,298.257222101]],PRIMEM['Greenwich',0.0],UNIT['Degree',0.0174532925199433]],PROJECTION['Transverse_Mercator'],PARAMETER['False_Easting',500000.0],PARAMETER['False_Northing',0.0],PARAMETER['Central_Meridian',-93.0],PARAMETER['Scale_Factor',0.9996],PARAMETER['Latitude_Of_Origin',0.0],UNIT['Meter',1.0]]", None, '', "NONE", None)
# Out:
# <Result 'C:\\Users\\celia\\Documents\\ArcGIS\\Projects\\Lab2_GIS5572\\Lab2_GIS5572.gdb\\gaudi'>

# %%
#now we can add our tiff files to the mosaic
arcpy.management.AddRastersToMosaicDataset("gaudi", "Raster Dataset", r"C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\PRISM_ppt_30yr_normal_4kmM2_all_bil\PRISM_ppt_30yr_normal_4kmM2_01_bil.bil;C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\PRISM_ppt_30yr_normal_4kmM2_all_bil\PRISM_ppt_30yr_normal_4kmM2_02_bil.bil;C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\PRISM_ppt_30yr_normal_4kmM2_all_bil\PRISM_ppt_30yr_normal_4kmM2_03_bil.bil;C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\PRISM_ppt_30yr_normal_4kmM2_all_bil\PRISM_ppt_30yr_normal_4kmM2_04_bil.bil;C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\PRISM_ppt_30yr_normal_4kmM2_all_bil\PRISM_ppt_30yr_normal_4kmM2_05_bil.bil;C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\PRISM_ppt_30yr_normal_4kmM2_all_bil\PRISM_ppt_30yr_normal_4kmM2_06_bil.bil;C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\PRISM_ppt_30yr_normal_4kmM2_all_bil\PRISM_ppt_30yr_normal_4kmM2_07_bil.bil;C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\PRISM_ppt_30yr_normal_4kmM2_all_bil\PRISM_ppt_30yr_normal_4kmM2_08_bil.bil;C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\PRISM_ppt_30yr_normal_4kmM2_all_bil\PRISM_ppt_30yr_normal_4kmM2_09_bil.bil;C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\PRISM_ppt_30yr_normal_4kmM2_all_bil\PRISM_ppt_30yr_normal_4kmM2_10_bil.bil;C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\PRISM_ppt_30yr_normal_4kmM2_all_bil\PRISM_ppt_30yr_normal_4kmM2_11_bil.bil;C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\PRISM_ppt_30yr_normal_4kmM2_all_bil\PRISM_ppt_30yr_normal_4kmM2_12_bil.bil", "UPDATE_CELL_SIZES", "UPDATE_BOUNDARY", "NO_OVERVIEWS", None, 0, 1500, None, '', "SUBFOLDERS", "ALLOW_DUPLICATES", "NO_PYRAMIDS", "NO_STATISTICS", "NO_THUMBNAILS", '', "NO_FORCE_SPATIAL_REFERENCE", "NO_STATISTICS", None, "NO_PIXEL_CACHE", r"C:\Users\celia\AppData\Local\ESRI\rasterproxies\mosaicfoot")

# %%
#create and populate the variable field as 'precipitation'

arcpy.management.CalculateField("gaudi", "variable", "'precipitation'", "PYTHON3", '', "TEXT")
# Out:
# <Result 'gaudi'>

# %%
#create and populate timestamp field

arcpy.management.AddField("gaudi", "timestamp", 'date')
arcpy.management.CalculateField("gaudi", "timestamp", """DateAdd(Date(2010,0,1), $feature.OBJECTID-1, 'month')
""", "ARCADE", '', "TEXT")
# Out:
# <Result 'gaudi'>

# %%
#now build the multidimensional info and make a multidimensional raster layer

arcpy.md.BuildMultidimensionalInfo("gaudi", "variable", "timestamp # #", "variable # #")
arcpy.md.MakeMultidimensionalRasterLayer("gaudi", "mosaic_Multi", "precipitation", "ALL", None, None, '', '', '', None, '', "-2871587.5494 2660354.42202726 3264899.3806283 6041683.9549", "DIMENSIONS")
# Out:
# <Result 'mosaic_Multi'>

# %%
#finally, create the spacetime cube
arcpy.stpm.CreateSpaceTimeCubeMDRasterLayer("mosaic_Multi", r"C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\mosaicTimeCube.nc", "ZEROS")

# %%
#but you can't see the result until you visualize it
arcpy.stpm.VisualizeSpaceTimeCube3D('PRISM_ppt_30yr_normal_4kmM2_.nc', cube_variable, display_theme, output_features)

#it's beautiful!

# %%
#I tried a lof of different ways to export the animation but none of them worked in the time I had
#export_map comes from the developer tools and it does not require you to use the GUI to make a layout first
#so it could potentially be used above. Howver, you need a json of the map and I could not successfully make or find one in time

#ExporttoGIF in the GUI does work
arcgis.mapping.export_map(web_map_as_json: str = None, format: str = 'GIF', layout_template: str = 'MAP_ONLY', gis=None)

# %%
arcpy.server.ExportWebMap("mosaic_Multi.json", r"C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\Animation.gif", "GIF", None, "MAP_ONLY")
# Out:
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# In  [11]:
# Line 1:     arcpy.server.ExportWebMap("mosaic_Multi.json", r"C:\Users\celia\Documents\ArcGIS\Projects\Lab2_GIS5572\Animation.gif", "GIF", None, "MAP_ONLY")
#
# File C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\server.py, in ExportWebMap:
# Line 1001:  raise e
#
# File C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\server.py, in ExportWebMap:
# Line 998:   retval = convertArcObjectToPythonObject(gp.ExportWebMap_server(*gp_fixargs((Web_Map_as_JSON, Output_File, Format, Layout_Templates_Folder, Layout_Template), True)))
#
# File C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py, in <lambda>:
# Line 511:   return lambda *args: val(*gp_fixargs(args, True))
#
# ExecuteError: Web map has invalid JSON.
# Failed to execute (ExportWebMap).
#
# ...
